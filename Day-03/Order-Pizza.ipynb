# %% [markdown]
# ![alt text](<Screenshot 2026-01-13 074223.png>)

# %%
print("Thank you for choosing Python Pizza Deliveries!\n")
size = input()
add_pepperoni = input()
extra_cheese = input()
bill = 0
add_pepperoni_small = 0
add_pep_M = 0
add_pep_L = 0

if size == "S":
    bill = 15
    if  add_pepperoni == "Y":
        bill = bill + 2
    elif add_pepperoni == "N":
        bill=bill        
    """ if extra_cheese == "Y":
        print(f"Your Final bill is: $ {bill + 1}")
    elif extra_cheese== "N":
        print(f"Your Final bill is: $ {bill}") """




if size == "M":
    bill = 20

    if  add_pepperoni == "Y":
        bill = bill + 3
        #print(f"Your Final bill is: $ {add_pep_M}")
    elif add_pepperoni== "N":
        bill=bill 

    """ if extra_cheese == "Y":
        print(f"Your Final bill is: $ {bill + 1}")
    elif extra_cheese == "N":
        print(f"Your Final bill is: $ {bill}") """
    



if size == "L":
    bill = 25
     
    if add_pepperoni == "Y":
        bill = bill + 3
        #print(f"Your Final bill is: $ {add_pep_L}")
    elif add_pepperoni == "N":
        bill=bill      

    """ if extra_cheese == "Y":
        print(f"Your Final bill is: $ {bill + 1}")
    elif extra_cheese == "N":
        print(f"Your Final bill is: $ {bill}") """


if extra_cheese == "Y":
        print(f"Your Final bill is: $ {bill + 1}")
elif extra_cheese== "N":
        print(f"Your Final bill is: $ {bill}")
# Out:
# Thank you for choosing Python Pizza Deliveries!
#
# Your Final bill is: $ 15
# Your Final bill is: $ 15
