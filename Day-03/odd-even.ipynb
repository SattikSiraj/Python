# %% [markdown]
# ## Wheater a input integer is even or odd

# %%
num = int(input())
if num%2 == 0:
    print("The number is Even.\n")
else:
    print("The number is Odd.\n")
# Out:
# The number is Even.
