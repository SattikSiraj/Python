# %%
names_string= input()
names = names_string.split(" ")
import random
total_names = len(names)
random_choice = random.randint(0, total_names-1)
pick_name = names[random_choice]
print(f"{pick_name} is the choosen name!")
# Out:
# nira is the choosen name!
