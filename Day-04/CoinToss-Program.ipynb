# %% [markdown]
# #### Virtual Coin Toss Program
# - Randomly Generated

# %%
import random
coin_toss = random.randint(0,1)
if coin_toss == 1:
    print("Heads\n")
elif coin_toss == 0:
    print("Tails\n")
# Out:
# Heads
