# %%
dirty_dozen = ["Strawberries", "Spinach", "Kale", "Nectarines", "Apples", "Grapes", "Peaches",
                "Cherries", "Pears", "Tomatoes", "Celery", "Potatoes"]

fruits= ["Strawberries", "Nectarines", "Apples", "Grapes", "Peaches", "Cherries", "Pears"]
vegetables = ["Tomatoes", "Celery", "Potatoes", "Spinach", "Kale"]
dirty_dozen = [fruits, vegetables]
print(dirty_dozen)

print(dirty_dozen[0]) #Output: First List
print(dirty_dozen[1]) #Output: Second List

print(dirty_dozen[0][0]) # Output : Strawberries
print(dirty_dozen[0][1]) # Output : Nectarines
print(dirty_dozen[0][2]) # Output : Apples

print(dirty_dozen[1][0]) #Output: Tomatoes
print(dirty_dozen[1][1]) #Output: Celery
print(dirty_dozen[1][2]) #Output: Potatoes
# Out:
# [['Strawberries', 'Nectarines', 'Apples', 'Grapes', 'Peaches', 'Cherries', 'Pears'], ['Tomatoes', 'Celery', 'Potatoes', 'Spinach', 'Kale']]
# ['Strawberries', 'Nectarines', 'Apples', 'Grapes', 'Peaches', 'Cherries', 'Pears']
# ['Tomatoes', 'Celery', 'Potatoes', 'Spinach', 'Kale']
# Strawberries
# Nectarines
# Apples
# Tomatoes
# Celery
# Potatoes
