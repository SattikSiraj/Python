# %% [markdown]
# # Life in weeks
# Let's consider average human life is 90 years
# it will take input of your current age and gives the output containing a string with how many weeks you have left.

# %%
age = int(input())
total_age = 90
years_left = 90 - int(age)
weeks = years_left * 52
print(f"You have {weeks} weeks left.")
# Out:
# You have 1768 weeks left.
