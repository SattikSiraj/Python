# %% [markdown]
# # F-String
#
# - Inserting different datatypes into a string

# %%
score = 0
height = 1.5
isWinning = True
print(f"your score is {score}, your height is {height}, you're winning is {isWinning}")
# Out:
# your score is 0, your height is 1.5, you're winning is True
